# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.2.36)
# Requirement already satisfied: pandas>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance) (2.2.0)
# Requirement already satisfied: numpy>=1.16.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance) (5.1.0)
# Requirement already satisfied: appdirs>=1.4.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /Users/apoorv/Library/Python/3.10/lib/python/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/apoorv/Library/Python/3.10/lib/python/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/apoorv/Library/Python/3.10/lib/python/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/apoorv/Library/Python/3.10/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/apoorv/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib as mpl

# %%
initial_data = yf.download("AAPL AMZN META GOOG MSFT TSLA SPY ^VIX", start="2023-02-23", end="2024-02-23")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [                       0%%                      ]/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [                       0%%                      ]/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************50%%                      ]  4 of 8 completed/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************62%%****                  ]  5 of 8 completed/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [**********************75%%**********            ]  6 of 8 completed/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/yfinance/utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  8 of 8 completed

# %%
initial_data.head()
# Out:
# Price        Adj Close                                                \
# Ticker            AAPL       AMZN       GOOG        META        MSFT
# Date
# 2023-02-23  148.606781  95.820000  91.070000  171.857651  252.696045
# 2023-02-24  145.931061  93.500000  89.349998  170.209412  247.191238
# 2023-02-27  147.134644  93.760002  90.099998  169.360306  248.123581
# 2023-02-28  146.627350  94.230003  90.300003  174.754593  247.389603
# 2023-03-01  144.538513  92.169998  90.510002  173.236191  244.265244
#
# Price                                               Close             ...  \
# Ticker             SPY        TSLA       ^VIX        AAPL       AMZN  ...
# Date                                                                  ...
# 2023-02-23  394.661682  202.070007  21.139999  149.399994  95.820000  ...
# 2023-02-24  390.445740  196.880005  21.670000  146.710007  93.500000  ...
# 2023-02-27  391.775543  207.630005  20.950001  147.919998  93.760002  ...
# 2023-02-28  390.327545  205.710007  20.700001  147.410004  94.230003  ...
# 2023-03-01  388.830292  202.770004  20.580000  145.309998  92.169998  ...
#
# Price             Open               Volume                                \
# Ticker            TSLA       ^VIX      AAPL      AMZN      GOOG      META
# Date
# 2023-02-23  203.910004  21.959999  48394200  48467000  32423700  20017800
# 2023-02-24  196.330002  21.350000  55469600  57053800  31295600  19791300
# 2023-02-27  202.029999  21.990000  44998500  47470300  22724300  19277000
# 2023-02-28  210.589996  21.299999  50547000  43959300  30546900  46051100
# 2023-03-01  206.210007  20.389999  55479000  52299500  26323900  30998400
#
# Price
# Ticker          MSFT        SPY       TSLA ^VIX
# Date
# 2023-02-23  29219100   96242400  146360000    0
# 2023-02-24  24990900  108194400  142228100    0
# 2023-02-27  21190000   80444700  161028300    0
# 2023-02-28  22491000   96438600  153144900    0
# 2023-03-01  27565300   99706800  156852800    0
#
# [5 rows x 48 columns]

# %%
initial_data['Adj Close'].head()
# Out:
# Ticker            AAPL       AMZN       GOOG        META        MSFT  \
# Date
# 2023-02-23  148.606781  95.820000  91.070000  171.857651  252.696045
# 2023-02-24  145.931061  93.500000  89.349998  170.209412  247.191238
# 2023-02-27  147.134644  93.760002  90.099998  169.360306  248.123581
# 2023-02-28  146.627350  94.230003  90.300003  174.754593  247.389603
# 2023-03-01  144.538513  92.169998  90.510002  173.236191  244.265244
#
# Ticker             SPY        TSLA       ^VIX
# Date
# 2023-02-23  394.661682  202.070007  21.139999
# 2023-02-24  390.445740  196.880005  21.670000
# 2023-02-27  391.775543  207.630005  20.950001
# 2023-02-28  390.327545  205.710007  20.700001
# 2023-03-01  388.830292  202.770004  20.580000

# %%
initial_data['Adj Close'].tail()
# Out:
# Ticker            AAPL        AMZN        GOOG        META        MSFT  \
# Date
# 2024-02-15  183.860001  169.800003  143.940002  483.516968  406.559998
# 2024-02-16  182.309998  169.509995  141.759995  472.818329  404.059998
NaN       NaN       NaN       NaN       NaN       NaN
# 2023-02-24 -2.675720 -2.320000 -1.720001 -1.648239 -5.504807 -4.215942
# 2023-02-27  1.203583  0.260002  0.750000 -0.849106  0.932343  1.329803
# 2023-02-28 -0.507294  0.470001  0.200005  5.394287 -0.733978 -1.447998
# 2023-03-01 -2.088837 -2.060005  0.209999 -1.518402 -3.124359 -1.497253
#
# Ticker           TSLA      ^VIX
# Date
# 2023-02-23        NaN       NaN
# 2023-02-24  -5.190002  0.530001
# 2023-02-27  10.750000 -0.719999
# 2023-02-28  -1.919998 -0.250000
# 2023-03-01  -2.940002 -0.120001

# %%
data.diff().describe().round(2)
# Out:
# Ticker    AAPL    AMZN    GOOG    META    MSFT     SPY    TSLA    ^VIX
# count   250.00  250.00  250.00  250.00  250.00  250.00  250.00  250.00
# mean      0.14    0.32    0.22    1.26    0.64    0.45   -0.02   -0.03
# std       2.14    2.50    2.20    7.58    4.68    3.36    6.89    0.96
# min      -9.14   -7.17  -13.45  -15.56  -13.13   -8.01  -28.36   -3.15
# 25%      -1.13   -1.19   -1.04   -2.20   -2.30   -1.69   -3.96   -0.61
# 50%       0.11    0.14    0.30    0.52    0.59    0.32    0.21   -0.05
# 75%       1.38    1.78    1.42    4.35    3.80    2.73    3.68    0.42
# max       7.74   12.53    7.02   80.12   19.79   10.29   25.08    3.50

# %%
data.pct_change().round(4).head()
# Out:
# Ticker        AAPL    AMZN    GOOG    META    MSFT     SPY    TSLA    ^VIX
# Date
# 2023-02-23     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2023-02-24 -0.0180 -0.0242 -0.0189 -0.0096 -0.0218 -0.0107 -0.0257  0.0251
# 2023-02-27  0.0082  0.0028  0.0084 -0.0050  0.0038  0.0034  0.0546 -0.0332
# 2023-02-28 -0.0034  0.0050  0.0022  0.0319 -0.0030 -0.0037 -0.0092 -0.0119
# 2023-03-01 -0.0142 -0.0219  0.0023 -0.0087 -0.0126 -0.0038 -0.0143 -0.0058

# %%
data.pct_change().mean().plot(kind='bar', figsize=(10, 6));

# %%
rets = np.log(data / data.shift(1))
rets.head().round(4)
# Out:
# Ticker        AAPL    AMZN    GOOG    META    MSFT     SPY    TSLA    ^VIX
# Date
# 2023-02-23     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2023-02-24 -0.0182 -0.0245 -0.0191 -0.0096 -0.0220 -0.0107 -0.0260  0.0248
# 2023-02-27  0.0082  0.0028  0.0084 -0.0050  0.0038  0.0034  0.0532 -0.0338
# 2023-02-28 -0.0035  0.0050  0.0022  0.0314 -0.0030 -0.0037 -0.0093 -0.0120
# 2023-03-01 -0.0143 -0.0221  0.0023 -0.0087 -0.0127 -0.0038 -0.0144 -0.0058

# %%
rets.cumsum().apply(np.exp).plot(figsize=(10, 6));

# %%
data.resample('1W', label='right').last().head()
# Out:
# Ticker            AAPL       AMZN        GOOG        META        MSFT  \
# Date
# 2023-02-26  145.931061  93.500000   89.349998  170.209412  247.191238
# 2023-03-05  150.228119  94.900002   94.019997  185.053650  253.211792
# 2023-03-12  147.711548  90.730003   91.010002  179.319733  246.566360
# 2023-03-19  154.177048  98.949997  102.459999  195.402679  277.155334
# 2023-03-26  159.399170  98.129997  106.059998  205.791641  278.286041
#
# Ticker             SPY        TSLA       ^VIX
# Date
# 2023-02-26  390.445740  196.880005  21.670000
# 2023-03-05  398.138855  197.789993  18.490000
# 2023-03-12  380.132507  173.440002  24.799999
# 2023-03-19  385.617523  180.130005  25.510000
# 2023-03-26  391.312927  190.410004  21.740000

# %%
data.resample('1ME', label='right').last().head()
# Out:
# Ticker            AAPL        AMZN        GOOG        META        MSFT  \
# Date
# 2023-02-28  146.627350   94.230003   90.300003  174.754593  247.389603
# 2023-03-31  164.024490  103.290001  104.000000  211.715363  285.953064
# 2023-04-30  168.779099  105.449997  108.220001  240.065292  304.758759
# 2023-05-31  176.552780  120.580002  123.370003  264.439423  326.428802
# 2023-06-30  193.207031  130.360001  120.970001  286.675842  338.506226
#
# Ticker             SPY        TSLA       ^VIX
# Date
# 2023-02-28  390.327545  205.710007  20.700001
# 2023-03-31  404.800049  207.460007  18.700001
# 2023-04-30  411.266724  164.309998  15.780000
# 2023-05-31  413.165192  203.929993  17.940001
# 2023-06-30  439.938202  261.769989  13.590000

# %%
rets.cumsum().apply(np.exp). resample('1w', label='right').last().plot(figsize=(10, 6))
# Out:
# /var/folders/x1/ry64pgdx6bx1jt4_whz7d2_80000gn/T/ipykernel_1121/490454790.py:1: FutureWarning: 'w' is deprecated and will be removed in a future version, please use 'W' instead.
#   rets.cumsum().apply(np.exp). resample('1w', label='right').last().plot(figsize=(10, 6))
# <Axes: xlabel='Date'>

# %%
rets.cumsum().apply(np.exp). resample('1m', label='right').last().plot(figsize=(10, 6))
# Out:
# /var/folders/x1/ry64pgdx6bx1jt4_whz7d2_80000gn/T/ipykernel_1121/232192763.py:1: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   rets.cumsum().apply(np.exp). resample('1m', label='right').last().plot(figsize=(10, 6))
# <Axes: xlabel='Date'>

# %%
sym = 'AAPL'
AAPL_data = pd.DataFrame(data[sym]).dropna()
AAPL_data.tail()
# Out:
#                   AAPL
# Date
# 2024-02-15  183.860001
# 2024-02-16  182.309998
# 2024-02-20  181.559998
# 2024-02-21  182.320007
# 2024-02-22  184.369995

# %%
sym = 'AAPL'
AAPL_data = pd.DataFrame(data[sym]).dropna()
AAPL_data.head()
# Out:
#                   AAPL
# Date
# 2023-02-23  148.606781
# 2023-02-24  145.931061
# 2023-02-27  147.134644
# 2023-02-28  146.627350
# 2023-03-01  144.538513

# %%
window = 10
AAPL_data['min'] = data[sym].rolling(window=window).min()
AAPL_data['mean'] = data[sym].rolling(window=window).mean()
AAPL_data['std'] = data[sym].rolling(window=window).std()
AAPL_data['median'] = data[sym].rolling(window=window).median()
AAPL_data['max'] = data[sym].rolling(window=window).max()
AAPL_data['ewma'] = data[sym].ewm(halflife=0.5, min_periods=window).mean()
AAPL_data.dropna().head()
# Out:
#                   AAPL         min        mean       std      median  \
# Date
# 2023-03-08  152.058365  144.538513  148.406854  2.985059  147.870712
# 2023-03-09  149.790466  144.538513  148.525223  3.017163  148.462555
# 2023-03-10  147.711548  144.538513  148.703271  2.897218  148.751007
# 2023-03-13  149.671097  144.538513  148.956917  2.855357  149.730782
# 2023-03-14  151.779846  144.538513  149.472166  2.853162  150.009293
#
#                    max        ewma
# Date
# 2023-03-08  153.013275  151.817730
# 2023-03-09  153.013275  150.297282
# 2023-03-10  153.013275  148.357981
# 2023-03-13  153.013275  149.342818
# 2023-03-14  153.013275  151.170589

# %%
 ax = AAPL_data[['min', 'mean', 'max']].iloc[-200:].plot(figsize=(10, 6), style=['g--', 'r--', 'g--'], lw=0.8)
data[sym].iloc[-200:].plot(ax=ax, lw=2.0);

# %%
AAPL_data['SMA1'] = data[sym].rolling(window=20).mean()
AAPL_data['SMA2'] = data[sym].rolling(window=60).mean()
AAPL_data[[sym, 'SMA1', 'SMA2']].tail()
# Out:
#                   AAPL        SMA1        SMA2
# Date
# 2024-02-15  183.860001  188.936185  189.906265
# 2024-02-16  182.309998  188.485892  189.757998
# 2024-02-20  181.559998  187.881747  189.610714
# 2024-02-21  182.320007  187.251184  189.464944
# 2024-02-22  184.369995  186.757078  189.375646

# %%
AAPL_data[[sym, 'SMA1', 'SMA2']].plot(figsize=(10, 6))
# Out:
# <Axes: xlabel='Date'>

# %%
AAPL_data.dropna(inplace=True)
AAPL_data['positions'] = np.where(AAPL_data['SMA1'] > AAPL_data['SMA2'],1,-1)
ax = AAPL_data[[sym, 'SMA1', 'SMA2', 'positions']].plot(figsize=(10, 6),secondary_y='positions')
ax.get_legend().set_bbox_to_anchor((0.25, 0.85))

# %%
Corr_data = data[['SPY', '^VIX']].dropna()
Corr_data.tail()
# Out:
# Ticker             SPY   ^VIX
# Date
# 2024-02-15  502.010010  14.01
# 2024-02-16  499.510010  14.24
# 2024-02-20  496.760010  15.42
# 2024-02-21  497.209991  15.34
# 2024-02-22  507.500000  14.54

# %%
Corr_data.plot(subplots=True, figsize=(10, 6))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
Corr_data.loc['2020-01-01':].plot(secondary_y='^VIX', figsize=(10, 6));

# %%
sprets = np.log(Corr_data / Corr_data.shift(1))
sprets.head()
# Out:
# Ticker           SPY      ^VIX
# Date
# 2023-02-23       NaN       NaN
# 2023-02-24 -0.010740  0.024762
# 2023-02-27  0.003400 -0.033790
# 2023-02-28 -0.003703 -0.012005
# 2023-03-01 -0.003843 -0.005814

# %%
sprets.dropna(inplace=True)
sprets.plot(subplots=True, figsize=(10, 6))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
pd.plotting.scatter_matrix(sprets, alpha=0.2, diagonal='hist', hist_kwds={'bins': 35}, figsize=(10, 6))
# Out:
# array([[<Axes: xlabel='SPY', ylabel='SPY'>,
#         <Axes: xlabel='^VIX', ylabel='SPY'>],
#        [<Axes: xlabel='SPY', ylabel='^VIX'>,
#         <Axes: xlabel='^VIX', ylabel='^VIX'>]], dtype=object)

# %%
reg = np.polyfit(sprets['SPY'], sprets['^VIX'], deg=1)
ax = sprets.plot(kind='scatter', x='SPY', y='^VIX', figsize=(10, 6))
ax.plot(sprets['SPY'], np.polyval(reg, sprets['SPY']), 'r', lw=2);

# %%
sprets.corr()
# Out:
# Ticker       SPY      ^VIX
# Ticker
# SPY     1.000000 -0.752847
# ^VIX   -0.752847  1.000000

# %%
ax = sprets['SPY'].rolling(window=20).corr(sprets['^VIX']).plot(figsize=(10, 6)) 
ax.axhline(sprets.corr().iloc[0, 1], c='r');
